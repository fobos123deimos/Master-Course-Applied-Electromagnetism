# %% [markdown]
# <a href="https://colab.research.google.com/github/matheus123deimos/Master_Course_Applied_Electromagnetism/blob/main/notebooks/dieletric_reflection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problems
#
#
# <img src="https://drive.google.com/uc?export=view&id=1n0IcIcs17W913rekiS8D4fXizmK8RPC_" alt="drawing" width="400">
#
# <img src="https://drive.google.com/uc?export=view&id=16MXV7msP5tELdfqYmKG-F5miDx62qlBx" alt="drawing" width="500">
# $$$$
# $$$$
# $$$$
# <img src="https://drive.google.com/uc?export=view&id=1nNN5niNiB8T1REh7ezJ_guBpfULyLPEJ" alt="drawing" width="600">

# %%
# @title Imports
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import math

# %% [markdown]
# ### Exemple 5-9 : plots for one section
#
# $$$$
#
# 1. $$|\Gamma_{in}| = \Bigg|\displaystyle\frac{\Gamma_{12}+\Gamma_{23}e^{-j2\pi(f/f_{0})}}{1+\Gamma_{12}\Gamma_{23}e^{-j2\pi(f/f_{0})}}\Bigg|$$
#
# $$$$
#
# 2. $$5 GHz \le f \le 30GHz$$
#
# $$$$
#
# 3. $$ϵ_{r_{2}} = 3.7$$
#
# $$$$

# %%
#@title b) $f_{0} = 10$ GHz

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_r2 = 3.7 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz
Gamma12_value =  (1-np.sqrt(e_r2))/(1+np.sqrt(e_r2)) # Value of Gamma12
Gamma23_value = -Gamma12_value  # Value of Gamma23



# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs((Gamma12_value + Gamma23_value * np.exp(-1j * 2*np.pi * freq / f0_value)) / (1 + Gamma12_value * Gamma23_value * np.exp(-1j * 2 * np.pi * freq / f0_value)))
    gamma_in_values.append(value)


# Create the plot with Plotly
fig = px.line(x=frequencies, y=gamma_in_values, labels={'x': 'Frequency (GHz)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Frequency', xaxis_title='Frequency (GHz)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title b) $f_{0} = 20$ GHz

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 20 #@param
e_r2 = 3.7 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz
Gamma12_value =  (1-np.sqrt(e_r2))/(1+np.sqrt(e_r2)) # Value of Gamma12
Gamma23_value = -Gamma12_value  # Value of Gamma23



# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs((Gamma12_value + Gamma23_value * np.exp(-1j * 2*np.pi * freq / f0_value)) / (1 + Gamma12_value * Gamma23_value * np.exp(-1j * 2 * np.pi * freq / f0_value)))
    gamma_in_values.append(value)


# Create the plot with Plotly
fig = px.line(x=frequencies, y=gamma_in_values, labels={'x': 'Frequency (GHz)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Frequency', xaxis_title='Frequency (GHz)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title Problem 5.41 - d) Exact Tramission Line Model: $\quad |\Gamma_{in}(z = -d^{-}))| = \displaystyle\frac{Z(z=-d^{+})-\eta_{1}}{Z(z=-d^{+})+\eta_{1}}$

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_r2 = 3.7 #@param

eta_1 = 377
eta_2 = eta_1/np.sqrt(e_r2)
eta_3 = eta_1

sum_32 = eta_3 + eta_2
sub_32 = eta_3 - eta_2


frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz

# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs((eta_2*(sum_32 +sub_32*np.exp(-1j * 2 * np.pi * freq / f0_value)) -  eta_1*(sum_32 - sub_32*np.exp(-1j * 2 * np.pi * freq / f0_value)))/
                (eta_2*(sum_32 +sub_32*np.exp(-1j * 2 * np.pi * freq / f0_value)) +  eta_1*(sum_32 - sub_32*np.exp(-1j * 2 * np.pi * freq / f0_value))))
    gamma_in_values.append(value)

# Create the plot with Plotly
fig = px.line(x=frequencies, y=gamma_in_values, labels={'x': 'Frequency (GHz)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Frequency', xaxis_title='Frequency (GHz)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title Problem 5.41 - e) Exact Ray-Tracing Model: $\quad|\Gamma_{in}| = \Bigg|\displaystyle\frac{\Gamma_{12}+\Gamma_{23}e^{-j\pi(f/f_{0})}}{1+\Gamma_{12}\Gamma_{23}e^{-j\pi(f/f_{0})}}\Bigg|$

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_r2 = 3.7 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz
Gamma12_value =  (1-np.sqrt(e_r2))/(1+np.sqrt(e_r2)) # Value of Gamma12
Gamma23_value = -Gamma12_value  # Value of Gamma23



# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs((Gamma12_value + Gamma23_value * np.exp(-1j * 2*np.pi * freq / f0_value)) / (1 + Gamma12_value * Gamma23_value * np.exp(-1j * 2 * np.pi * freq / f0_value)))
    gamma_in_values.append(value)


# Create the plot with Plotly
fig = px.line(x=frequencies, y=gamma_in_values, labels={'x': 'Frequency (GHz)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Frequency', xaxis_title='Frequency (GHz)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title Problem 5.41 - d) Aproximate Ray-Tracing Model:  $\quad |\Gamma_{in}| \simeq \Gamma_{12} + \Gamma_{23}e^{-j\pi(f/f_{0})} \quad ;\quad |\Gamma_{12}|<<1 \quad ;\quad |\Gamma_{23}|<<1$

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_r2 = 3.7 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz
Gamma12_value =  (1-np.sqrt(e_r2))/(1+np.sqrt(e_r2)) # Value of Gamma12
Gamma23_value = -Gamma12_value  # Value of Gamma23



# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs(Gamma12_value + Gamma23_value * np.exp(-1j * 2*np.pi * freq / f0_value))
    gamma_in_values.append(value)


# Create the plot with Plotly
fig = px.line(x=frequencies, y=gamma_in_values, labels={'x': 'Frequency (GHz)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Frequency', xaxis_title='Frequency (GHz)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Exemple 5-10 : plots for one section
#
# $$$$
# 1. $$|\Gamma_{in}| = \Bigg|\displaystyle\frac{\Gamma_{12}+\Gamma_{23}e^{-j\pi(f/f_{0})}}{1+\Gamma_{12}\Gamma_{23}e^{-j\pi(f/f_{0})}}\Bigg|$$
#
# $$$$
#
# 2. $$5 GHz \le f \le 30GHz$$
#
# $$$$
#
# 3. $$ϵ_{r_{3}} = ϵ_{r_{2}} + 2 = 5.7$$

# %%
#@title a) $f_{0} = 10$ GHz

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_r2 = 3.7 #@param
e_r3 = 5.7 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz
Gamma12_value =  (1-np.sqrt(e_r2))/(1+np.sqrt(e_r2)) # Value of Gamma12
Gamma23_value = ((1/np.sqrt(e_r3))-(1/np.sqrt(e_r2)))/((1/np.sqrt(e_r3))+(1/np.sqrt(e_r2)))  # Value of Gamma23

# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs((Gamma12_value + Gamma23_value * np.exp(-1j * np.pi * freq / f0_value)) / (1 + Gamma12_value * Gamma23_value * np.exp(-1j * np.pi * freq / f0_value)))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title a) $f_{0} = 20$ GHz

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 20 #@param
e_r2 = 3.7 #@param
e_r3 = 5.7 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz
Gamma12_value =  (1-np.sqrt(e_r2))/(1+np.sqrt(e_r2)) # Value of Gamma12
Gamma23_value = ((1/np.sqrt(e_r3))-(1/np.sqrt(e_r2)))/((1/np.sqrt(e_r3))+(1/np.sqrt(e_r2)))  # Value of Gamma23

# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs((Gamma12_value + Gamma23_value * np.exp(-1j * np.pi * freq / f0_value)) / (1 + Gamma12_value * Gamma23_value * np.exp(-1j * np.pi * freq / f0_value)))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title Problem 5.41 - g) Exact Tramission Line Model: $\quad |\Gamma_{in}(z = -d^{-}))| = \displaystyle\frac{Z(z=-d^{+})-\eta_{1}}{Z(z=-d^{+})+\eta_{1}}$

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_r2 = 3.7 #@param
e_r3 = 5.7 #@param

eta_1 = 377
eta_2 = eta_1/np.sqrt(e_r2)
eta_3 = eta_1/np.sqrt(e_r3)

sum_32 = eta_3 + eta_2
sub_32 = eta_3 - eta_2


frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz

# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs((eta_2*(sum_32 +sub_32*np.exp(-1j  * np.pi * freq / f0_value)) -  eta_1*(sum_32 - sub_32*np.exp(-1j  * np.pi * freq / f0_value)))/
                (eta_2*(sum_32 +sub_32*np.exp(-1j  * np.pi * freq / f0_value)) +  eta_1*(sum_32 - sub_32*np.exp(-1j  * np.pi * freq / f0_value))))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title Problem 5.41 - h) Exact Ray-Tracing Model: $\quad|\Gamma_{in}| = \Bigg|\displaystyle\frac{\Gamma_{12}+\Gamma_{23}e^{-j\pi(f/f_{0})}}{1+\Gamma_{12}\Gamma_{23}e^{-j\pi(f/f_{0})}}\Bigg|$

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_r2 = 3.7 #@param
e_r3 = 5.7 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz
Gamma12_value =  (1-np.sqrt(e_r2))/(1+np.sqrt(e_r2)) # Value of Gamma12
Gamma23_value = ((1/np.sqrt(e_r3))-(1/np.sqrt(e_r2)))/((1/np.sqrt(e_r3))+(1/np.sqrt(e_r2)))  # Value of Gamma23

# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs((Gamma12_value + Gamma23_value * np.exp(-1j * np.pi * freq / f0_value)) / (1 + Gamma12_value * Gamma23_value * np.exp(-1j * np.pi * freq / f0_value)))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title Problem 5.41 - i) $\quad |\Gamma_{in}| \simeq \Gamma_{12} + \Gamma_{23}e^{-j\pi(f/f_{0})} \quad ;\quad |\Gamma_{12}|<<1 \quad ;\quad |\Gamma_{23}|<<1$

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_r2 = 3.7 #@param
e_r3 = 5.7 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz
Gamma12_value =  (1-np.sqrt(e_r2))/(1+np.sqrt(e_r2)) # Value of Gamma12
Gamma23_value = ((1/np.sqrt(e_r3))-(1/np.sqrt(e_r2)))/((1/np.sqrt(e_r3))+(1/np.sqrt(e_r2)))  # Value of Gamma23

# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs(Gamma12_value + Gamma23_value * np.exp(-1j * np.pi * freq / f0_value))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Exemple 5-11 : plots for two sections
#
# $$$$
# ### Binomial
# $$$$
#
# 1. $$\Gamma_{in}(f) \simeq \displaystyle\sum^{N}_{n=0}\Gamma_{n} e^{-j2n\theta} = e^{-jN\theta}\Bigg(\frac{\eta_{L} - \eta_{0}}{\eta_{L}+\eta_{0}}\Bigg)cos^{N}(\theta) \simeq 2^{-N}\Bigg(\frac{\eta_{L} - \eta_{0}}{\eta_{L}+\eta_{0}}\Bigg)\sum^{N}_{n=0}C^{N}_{n}e^{-j2n\theta}$$
#
# $$$$
#
# 2. $$C^{N}_{n} = \displaystyle\frac{N!}{(N-n)!n!} \qquad n = 0,1,2,...,N$$
#
# $$$$
#
# 3. $$\Gamma_{n} = 2^{-N}\Bigg(\frac{\eta_{L} - \eta_{0}}{\eta_{L}+\eta_{0}}\Bigg)C^{N}_{n}$$
#
# $$$$
#
# 4. $$\theta = \beta_{n}d_{n} = \displaystyle \Bigg(\frac{2\pi}{\lambda_{n}}\Bigg)\Bigg(\frac{\lambda_{n_{0}}}{4}\Bigg)=\displaystyle\frac{\pi}{2}\Bigg(\frac{f}{f_{0}}\Bigg)$$
#
# $$$$
#
# 5. $$5 GHz \le f \le 30GHz$$
#
# $$$$
#
# 6. $$ϵ_{r_{3}} = ϵ_{r_{2}} + 3 = 6.7$$

# %%
#@title a) $f_{0} = 10$ GHz

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_L = 6.7 #@param
N = 2 #@param

frequencies = np.linspace(f_min, f_max, n_size)
eta_L = 377/np.sqrt(e_L)

exp_1 = (eta_L-377)/(eta_L+377)

C_n = lambda n: (math.factorial(N)/(math.factorial(N-n)*math.factorial(n)))

bin_aproximation = lambda fm : 2**(-N) * exp_1 * sum([ C_n(n)*np.exp(-1j*n*np.pi * fm / f0_value) for n in range(N+1) ])


# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs(bin_aproximation(freq))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title a) $f_{0} = 20$ GHz

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 20 #@param
e_L = 6.7 #@param
N = 2 #@param

frequencies = np.linspace(f_min, f_max, n_size)
eta_L = 377/np.sqrt(e_L)

exp_1 = (eta_L-377)/(eta_L+377)

C_n = lambda n: (math.factorial(N)/(math.factorial(N-n)*math.factorial(n)))

bin_aproximation = lambda fm : 2**(-N) * exp_1 * sum([ C_n(n)*np.exp(-1j*n*np.pi * fm / f0_value) for n in range(N+1) ])


# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs(bin_aproximation(freq))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Exemple 5-11 : plots for two sections
#
# $$$$
# ### Tschebyscheff
# $$$$
#
# 1. $$\Gamma_{in}(f) = e^{-jN\theta}\Bigg\{\frac{\eta_{L} - \eta_{0}}{\eta_{L}+\eta_{0}}\Bigg\}\Bigg\{ \frac{T_{N}[sec(\theta_{m})cos(\theta)]}{T_{N}[sec(\theta_{m})]}\Bigg\}$$
#
# $$$$
#
# 2. $$T_{m}(z) = cos[m*arcos(z)] \qquad z \in [-1,+1] \quad ; \qquad T_{m}(z) = cosh[m*arcosh(z)] \qquad z>+1$$
#
# $$\quad ; \qquad T_{m}(z) = (-1)^{m}cosh[m*arcosh(-z)] \qquad z<-1$$
#
# $$$$
#
# 3. $$\theta_{m} = \displaystyle\frac{\pi}{4}\Bigg(2 - \frac{\Delta f}{f_{0}} \Bigg)$$
#
# $$$$
#
# 4. $$\theta = \beta_{n}d_{n} = \displaystyle \Bigg(\frac{2\pi}{\lambda_{n}}\Bigg)\Bigg(\frac{\lambda_{n_{0}}}{4}\Bigg)=\displaystyle\frac{\pi}{2}\Bigg(\frac{f}{f_{0}}\Bigg)$$
#
# $$$$
#
# 5. $$5 GHz \le f \le 30GHz$$
#
# $$$$
#
# 6. $$ϵ_{r_{3}} = ϵ_{r_{2}} + 3 = 6.7$$

# %%
#@title a) $f_{0} = 10$ GHz

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_L = 6.7 #@param
N = 2 #@param
fractional_bandwidth = 0.375 #@param



frequencies = np.linspace(f_min, f_max, n_size)
theta_m = (np.pi/4)*(2-fractional_bandwidth)
eta_L = 377/np.sqrt(e_L)
exp_1 = (eta_L-377)/(eta_L+377)

exp_2 = lambda f : np.exp(-1j*N*((np.pi*f)/(2*f0_value)))

def Tmz(m,z):

  if(z<1 and z> -1):
    return math.cos(m*math.acos(z))
  elif(z>=1):
    return math.cosh(m*math.acosh(z))
  else:
    return ((-1)**m)*math.cosh(m*math.acosh(-z))

tschebyscheff_aproximation = lambda f : exp_2(f)*exp_1*(Tmz(N,(math.cos(theta_m)**(-1))*math.cos(np.pi*(f/(2*f0_value))))/Tmz(N,math.cos(theta_m)**(-1)))

#tschebyscheff_aproximation = lambda f : 0.174*math.cos(2*np.pi*(f/(2*f0_value))) + 0.1503

# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs(tschebyscheff_aproximation(freq))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#@title a) $f_{0} = 20$ GHz

f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 20 #@param
e_L = 6.7 #@param
N = 2 #@param
fractional_bandwidth = 0.375 #@param



frequencies = np.linspace(f_min, f_max, n_size)
theta_m = (np.pi/4)*(2-fractional_bandwidth)
eta_L = 377/np.sqrt(e_L)
exp_1 = (eta_L-377)/(eta_L+377)

exp_2 = lambda f : np.exp(-1j*N*((np.pi*f)/(2*f0_value)))

def Tmz(m,z):

  if(z<1 and z> -1):
    return math.cos(m*math.acos(z))
  elif(z>=1):
    return math.cosh(m*math.acosh(z))
  else:
    return ((-1)**m)*math.cosh(m*math.acosh(-z))

tschebyscheff_aproximation = lambda f : exp_2(f)*exp_1*(Tmz(N,(math.cos(theta_m)**(-1))*math.cos(np.pi*(f/(2*f0_value))))/Tmz(N,math.cos(theta_m)**(-1)))

# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values = []
for freq in frequencies:
    value = abs(tschebyscheff_aproximation(freq))
    gamma_in_values.append(value)

relative_frequencies = frequencies/f0_value

# Create the plot with Plotly
fig = px.line(x=relative_frequencies, y=gamma_in_values, labels={'x': 'Relative Frequency (f/f0)', 'y': 'Magnitude of the Input reflection coefficient |Γ_in|'})
fig.update_layout(title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)', xaxis_title='Relative Frequency (f/f0)', yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Exemple 5-11 : Binomial (2 sections) vs Tschebyscheff (2 sections) ($f_{0} = 10$ GHz)

# %%
f_min = 5 #@param
f_max = 30 #@param
n_size = 1000 #@param
f0_value = 10 #@param
e_L = 5.7 #@param
N = 2 #@param
fractional_bandwidth = 0.375 #@param

frequencies = np.linspace(f_min, f_max, n_size)  # Frequencies from 5 GHz to 30 GHz

eta_L = 377/np.sqrt(e_L)
exp_1 = (eta_L-377)/(eta_L+377)

C_n = lambda n: (math.factorial(N)/(math.factorial(N-n)*math.factorial(n)))
bin_aproximation = lambda fm : 2**(-N) * exp_1 * sum([ C_n(n)*np.exp(-1j*n*np.pi * fm / f0_value) for n in range(N+1) ])

theta_m = (np.pi/4)*(2-fractional_bandwidth)
exp_1 = (eta_L-377)/(eta_L+377)
exp_2 = lambda f : np.exp(-1j*N*((np.pi*f)/(2*f0_value)))

def Tmz(m,z):

  if(z<1 and z> -1):
    return math.cos(m*math.acos(z))
  elif(z>=1):
    return math.cosh(m*math.acosh(z))
  else:
    return ((-1)**m)*math.cosh(m*math.acosh(-z))

tschebyscheff_aproximation = lambda f : exp_2(f)*exp_1*(Tmz(N,(math.cos(theta_m)**(-1))*math.cos(np.pi*(f/(2*f0_value))))/Tmz(N,math.cos(theta_m)**(-1)))


# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values_binomial = []
for freq in frequencies:
    value = abs(bin_aproximation(freq))
    gamma_in_values_binomial.append(value)


# Calculate |Γ_in| for each frequency and convert to float
gamma_in_values_tch = []
for freq in frequencies:
    value = abs(tschebyscheff_aproximation(freq))
    gamma_in_values_tch.append(value)



relative_frequencies = frequencies/f0_value

fig = go.Figure()

y_highlight1 = 0.3
y_highlight2 = 0.4


fig.add_trace(go.Scatter(x=relative_frequencies, y=gamma_in_values_binomial, mode='lines', name='Binomial', line=dict(color='green', dash='dot')))
fig.add_trace(go.Scatter(x=relative_frequencies, y=gamma_in_values_tch, mode='lines', name='Tschebyscheff', line=dict(color='blue', dash='dashdot')))

fig.update_layout(
    title='Magnitude of the Input Reflection Coefficient vs. Relative Frequency (f/f0)',
    xaxis_title='Relative Frequency (f/f0)',
    yaxis_title='Magnitude of the Input reflection coefficient |Γ_in|',
    legend=dict(x=0, y=1, traceorder='normal', orientation='h')
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
